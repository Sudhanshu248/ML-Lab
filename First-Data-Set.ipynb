# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("DataSet.csv")

# %%
data
# Out:
#    Exp     sky  air temp  humidity     wind  water  forecast  enjoy
# 0    1   sunny      warm    normal   strong   warm      same    yes
# 1    2   sunny      warm      high   strong   warm      same    yes
# 2    3   rainy      cold      high   strong   warm    change     no
# 3    4   sunny      warm      high   strong   cold    change    yes

# %%
concepts = np.array(data)[:, :-1]

# %%
concepts
# Out:
# array([[1, ' sunny', ' warm', ' normal', ' strong', ' warm', ' same'],
#        [2, ' sunny', ' warm', ' high', ' strong', ' warm', ' same'],
#        [3, ' rainy', ' cold', ' high', ' strong', ' warm', ' change'],
#        [4, ' sunny', ' warm', ' high', ' strong', ' cold', ' change']],
#       dtype=object)

# %%
target = np.array(data)[:, -1]

# %%
target
# Out:
# array([' yes', ' yes', ' no', ' yes'], dtype=object)

# %%
def train(con, tar):
   
    for i, val in enumerate(tar):
        if val == "yes":
            specific_h = con[i].copy()
            break

    for i, val in enumerate(con):
        if tar[i] == "yes":
            for x in range(len(specific_h)):
                if val[x] != specific_h[x]:
                    specific_h[x] = "?"
                else:
                    pass
                    

    return specific_h

# %%
print(train(concepts, target))
# Out:
# None
